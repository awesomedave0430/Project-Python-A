# %%
import matplotlib
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import pandas as pd
Data = pd.read_csv('/content/MDcnty.csv')
x = Data['Life Expectancy']
y = Data['Census Tract Number']
plt.scatter(x, y, c=x, cmap='RdYlGn', edgecolors='k', alpha=0.7)
plt.xlabel("Life Expectancy (Years)")
plt.ylabel("Census Tract")
plt.title("Geography vs Life Miami-Dade")
plt.ylim(0, 210)
colorbar = plt.colorbar()
colorbar.set_label('Life Expectancy (Years)')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
Data = pd.read_csv('/content/MD Income.csv')
x = Data['Median Income in Thousands']
y = Data['Census Tract']
plt.scatter(x, y, c=x, cmap='RdYlGn', edgecolors='k', alpha=0.7)
plt.xlabel("Median Income in Thousands")
plt.ylabel("Census Tract")
plt.title("Geography vs Median Income Miami-Dade County")
plt.xticks(np.arange(4.8, 250, 40))
plt.ylim(0, 210)
colorbar = plt.colorbar()
colorbar.set_label('Median Income in Thousands')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
Data = pd.read_csv('/content/LAcnty.csv')
x = Data['Life Expectancy']
y = Data['Census Tract Number']
plt.scatter(x, y, c=x, cmap='RdYlGn', edgecolors='k', alpha=0.7)
plt.xlabel("Life Expectancy (Years)")
plt.ylabel("Census Tract")
plt.title("Geography vs Life Los Angeles County")
colorbar = plt.colorbar()
colorbar.set_label('Life Expectancy (Years)')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
Data = pd.read_csv('/content/LA Income.csv')
x = Data['Median Income in Thousands']
y = Data['Census Tract']
plt.scatter(x, y, c=x, cmap='RdYlGn', edgecolors='k', alpha=0.7)
plt.xlabel("Median Income in Thousands")
plt.ylabel("Census Tract")
plt.title("Geography vs Median Income LA County")
plt.xticks(np.arange(4.8, 250, 40))
colorbar = plt.colorbar()
colorbar.set_label('Median Income in Thousands')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
Data = pd.read_csv('/content/CookCounty.csv')
x = Data['Life Expectancy']
y = Data['Census Tract Number']
plt.scatter(x, y, c=x, cmap='RdYlGn', edgecolors='k', alpha=0.7)
plt.xlabel("Life Expectancy (Years)")
plt.ylabel("Census Tract")
plt.title("Geography vs Life Cook County")
colorbar = plt.colorbar()
colorbar.set_label('Life Expectancy (Years)')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
Data = pd.read_csv('/content/Cook Income.csv')
x = Data['Median Income In Thousands']
y = Data['Geographic Area Name']
plt.scatter(x, y, c=x, cmap='RdYlGn', edgecolors='k', alpha=0.7)
plt.xlabel("Median Income in Thousands")
plt.ylabel("Census Tract")
plt.title("Geography vs Median Income Cook County")
plt.xticks(np.arange(4.8, 250, 40))
colorbar = plt.colorbar()
colorbar.set_label('Median Income In Thousands')
plt.show()

# %%
Data=pd.read_csv(f'//content/LA Income.csv')
print(Data.head())
# Out:
#    Census Tract  Median Income  Margin of Error  Margin of Error in Thousands  \
# 0       2063.03           4918             2403                         4.918
# 1       2063.02           7193             6842                         7.193
# 2       2247.02           9722             3085                         9.722
# 3       2063.01          11153             2081                        11.153
# 4       2073.04          11430              783                        11.430
#
#    Median Income in Thousands
# 0                       4.918
# 1                       7.193
# 2                       9.722
# 3                      11.153
# 4                      11.430

# %%
Data=pd.read_csv(f'//content/MD Income.csv')
pd.DataFrame(Data)
# Out:
#      Census Tract  Median Income  Margin of Error  Median Income in Thousands
# 0           73.00         228644            95427                     228.644
# 1           78.01         216094            44839                     216.094
# 2           39.06         185972            28745                     185.972
# 3           81.01         185000            16788                     185.000
# 4           46.02         182067            66302                     182.067
# ..            ...            ...              ...                         ...
# 678          7.13          17364            16270                      17.364
# 679         18.03          17265             5635                      17.265
# 680          5.08          16635             6741                      16.635
# 681        113.01          15605             9531                      15.605
# 682         36.06          14079             6244                      14.079
#
# [683 rows x 4 columns]

# %%
Data=pd.read_csv(f'//content/Cook Income.csv')
pd.DataFrame(Data)
# Out:
#       Geographic Area Name  Median Income  Margin of Error  \
# 0                   8006.0         248571            33115
# 1                   8012.0         246806            46133
# 2                   8200.0         233977            42305
# 3                   8003.0         225417            61846
# 4                   8007.0         219792            40863
# ...                    ...            ...              ...
# 1315                8368.0          13733             4508
# 1316                3406.0          13207             4298
# 1317                4008.0          12896             8088
# 1318                6117.0          12421            11380
# 1319                3511.0          12328             3290
#
#       Median Income In Thousands
# 0                        248.571
# 1                        246.806
# 2                        233.977
# 3                        225.417
# 4                        219.792
# ...                          ...
# ...

# %%
Data=pd.read_csv(f'//content/LAcnty.csv')
print(Data.head())
# Out:
#         State                  County  Census Tract Number  Life Expectancy  \
# 0  California  Los Angeles County, CA              1011.10             79.2
# 1  California  Los Angeles County, CA              1011.22             80.0
# 2  California  Los Angeles County, CA              1012.10             82.5
# 3  California  Los Angeles County, CA              1012.20             78.5
# 4  California  Los Angeles County, CA              1013.00             80.0
#
#   Life Expectancy Range  Life Expectancy Standard Error
# 0             77.6-79.5                          2.0179
# 1             79.6-81.6                          1.4116
# 2             81.7-97.5                          3.9822
# 3             77.6-79.5                          2.5982
# 4             79.6-81.6                          3.1409

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-141-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...
